# %%
import pandas as pd
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = '/home/juan/Desktop/juan/bio/mirna_mite/data/res/%s/Results.txt'
path_annotation = '/home/juan/Desktop/juan/bio/mirna_mite/data/introns.gff3'
path_annotation_promoters = '/home/juan/Desktop/juan/bio/mirna_mite/data/promoters.gff3'
path_res = '/home/juan/Desktop/juan/bio/mirna_mite/data/res/all_results.csv'
path_mirna_seq = '/home/juan/Desktop/juan/bio/mirna_mite/data/res/mirna.y.fasta'
path_mirna_seq_trep = '/home/juan/Desktop/juan/bio/mirna_mite/data/res/mirna.y.trep.fasta'
path_mirna_mites_seq = '/home/juan/Desktop/juan/bio/mirna_mite/data/res/mirna.mites.y.fasta'
path_mirna_mature = '/home/juan/Desktop/juan/bio/mirna_mite/data/res/mirna.y.mature.csv'
path_res_seq = '/home/juan/Desktop/juan/bio/mirna_mite/data/res/all_results.fasta'
experiments = ['mrcv_mites','mrcv_all','sun_all','sun_mites']
path_genome = '/home/juan/Desktop/juan/bio/data/IWGSC/42/Triticum_aestivum.IWGSC.dna.toplevel.fa'
path_blast_res = '/home/juan/Desktop/juan/bio/mirna_mite/data/res/blast_mites.csv'
path_mirbase = '/home/juan/Desktop/juan/bio/mirna_mite/data/mature.fa'

# %%
### Load shortstack results
dfs = {}
for experiment in experiments:
    experiment_path = path % (experiment,)
    df = pd.read_csv(experiment_path, sep='\t')
    df['Name'] = experiment + '_' + df['Name']
    print('Experiment:', experiment)
    print('All results:',len(df.index))
    #df = df[df.MIRNA == 'Y']
    #print('Only miRNAs:',len(df.index))
    df = df[df.Reads > 15]
    print('Only miRNAs +20 reads:',len(df.index))
    df = df[df['21'] > 10]
    print('Only miRNAs 21nt +5 reads:',len(df.index))
    print('*' * 10)
    dfs[experiment] = df
# Out:
# Experiment: mrcv_mites
# All results: 1211339
# Only miRNAs +20 reads: 27597
# Only miRNAs 21nt +5 reads: 1751
# **********
# Experiment: mrcv_all
# All results: 38532
# Only miRNAs +20 reads: 38532
# Only miRNAs 21nt +5 reads: 10778
# **********
# Experiment: sun_all
# All results: 157492
# Only miRNAs +20 reads: 157492
# Only miRNAs 21nt +5 reads: 44964
# **********
# Experiment: sun_mites
# All results: 1211339
# Only miRNAs +20 reads: 62212
# Only miRNAs 21nt +5 reads: 3609
# **********

# %%
dfs = [ v for v in dfs.values() ]

# %%
df = pd.concat(dfs)

# %%
len(df.index)
# Out:
# 61102

# %%
df.head(2)
# Out:
#                  #Locus                                               Name  \
# 669  1A:7191963-7192334  mrcv_mites_MITE_T_7077|chr2B|403696383|4036967...
# 777  1A:8267612-8267880  mrcv_mites_MITE_T_22970|chr5A|493341243|493341...
#
#      Length  Reads    RPM  UniqueReads  FracTop Strand  \
# 669     372     65  0.510            4    0.031      -
# 777     269    122  0.957            9    0.361      .
#
#                      MajorRNA  MajorRNAReads ...  DicerCall MIRNA PhaseScore  \
# 669     UUUUUUGUCGAGAGUUGCUCA             36 ...         21   N15       -1.0
# 777  AGUUUGACUUCGGAGAAUUCUAAU             25 ...         24    N6        0.2
#
#      Short  Long  20  21  22  23  24
# 669      4     0  13  38   0   0  10
# 777      0     5   0  25   2   5  85
#
# [2 rows x 21 columns]

# %%
df['seqname'] = df['#Locus'].str.split(':').str[0]
df['position'] = df['#Locus'].str.split(':').str[1]
df['start'] = df.position.str.split('-').str[0].astype(int)
df['end'] = df.position.str.split('-').str[1].astype(int)

# %%
df = df.reset_index(drop=True)

# %%
print(len(df.index))
# Out:
# 61102

# %%
df[df.index.isin(['876749','876750','876751','27433'])]
# Out:
#                        #Locus                   Name  Length  Reads    RPM  \
# 27433  3B:262192194-262193584  sun_all_Cluster_55362    1391    457  3.619
#
#        UniqueReads  FracTop Strand                  MajorRNA  MajorRNAReads  \
# 27433          302    0.341      .  UGGAAAAAUAUAGGAUGGCCGAAU             16
#
#          ...      Long  20  21  22  23   24  seqname             position  \
# 27433    ...         4  18  25  25  46  317       3B  262192194-262193584
#
#            start        end
# 27433  262192194  262193584
#
# [1 rows x 25 columns]

# %%
min_distance = 60
duplicated = []
for k,v in df.iterrows():
    if k in duplicated:
        continue
    other = df[(df.index != k) & 
                (df.seqname == v.seqname) &
                (df.MajorRNA == v.MajorRNA) &
                (abs(df.start - v.start) <= min_distance) & 
                (abs(df.end - v.end) <= min_distance)]
    if len(other.index) > 0:
        duplicated += other.index.tolist()

# %%
duplicated = set(duplicated)
print(len(duplicated))
# Out:
# 1757

# %%
print(len(df.index))
# Out:
# 61102

# %%
df = df[~df.index.isin(duplicated)]
count_total = len(df.index)
count_total
# Out:
# 59345

# %%
df.MIRNA.value_counts()
# Out:
# N6     28157
# N11    10284
# N2      8300
# N5      7961
# N14     1213
# N12     1003
# N13      997
# N15      911
# Y        260
# N4       231
# N8        28
# Name: MIRNA, dtype: int64

# %%
df.MIRNA.value_counts().plot('bar')

# %%
len(df[df.MIRNA == 'Y'].index)
# Out:
# 260

# %%
df = df[df.MIRNA == 'Y']
print('Only miRNAs:',len(df.index))
# Out:
# Only miRNAs: 260

# %%
df.head(3)
# Out:
#                      #Locus  \
# 125  1D:147896240-147896319
# 223  2A:168984136-168984233
# 510    3A:19302861-19302943
#
#                                                   Name  Length  Reads    RPM  \
# 125  mrcv_mites_MITE_T_120271|chr2D|74975911|749759...      80     45  0.353
# 223  mrcv_mites_MITE_T_102616|chr1B|301273397|30127...      98    198  1.554
# 510  mrcv_mites_MITE_T_105526|chr3A|638201844|63820...      83    108  0.848
#
#      UniqueReads  FracTop Strand                MajorRNA  MajorRNAReads  \
# 125            1    1.000      +   UAUAUUUUGGUACGGAGGGAU             22
# 223            2    0.045      -  UCGGAAUUAGUUGACACUCAAA             86
# 510           10    0.972      +   UCCAAUUACUCGUCGUGGUUU             89
#
#        ...      Long 20  21  22  23  24  seqname             position  \
# 125    ...         4  2  38   1   0   0       1D  147896240-147896319
# 223    ...         1  1  39  89  63   1       2A  168984136-168984233
# 510    ...         2  0  99   4   0   3       3A    19302861-19302943
#
#          start        end
# 125  147896240  147896319
# 223  168984136  168984233
# 510   19302861   19302943
#
# [3 rows x 25 columns]

# %%
df_mites = df[df.Name.str.contains('MITE')]
count_mites = len(df_mites.index)
count_mites
# Out:
# 18

# %%
df_nomites = df[~df.Name.str.contains('MITE')]
count_nomites = len(df_nomites.index)
count_nomites
# Out:
# 242

# %%
count_mites * 100 / count_total
# Out:
# 0.030331114668464065

# %%
#get sequences
df.sort_values(['seqname', 'start'], inplace=True)

# %%
fasta_seq = SeqIO.parse(path_genome, 'fasta')

# %%
buffer_seqs = []
for record in fasta_seq:
    dff_extract = df[df.seqname == record.id]
    print(record.id, len(dff_extract.index))
    clean_seq = ''.join(str(record.seq).splitlines())
    for k,v in dff_extract.iterrows():
        start = min(v.start,v.end)
        end = max(v.start,v.end)
        new_seq = clean_seq[start:end]
        id = v.Name
        desc = record.id + "_" + str(start) + '_' + str(end)
        seq = SeqRecord(Seq(new_seq), id=id, description=desc)
        buffer_seqs.append(seq)
SeqIO.write(buffer_seqs, path_res_seq, "fasta")
print(path_res_seq)
# Out:
# 1A 5
# 1B 6
# 1D 6
# 2A 13
# 2B 18
# 2D 5
# 3A 10
# 3B 9
# 3D 11
# 4A 15
# 4B 8
# 4D 9
# 5A 20
# 5B 16
# 5D 20
# 6A 18
# 6B 17
# 6D 16
# 7A 14
# 7B 17
# 7D 5
# Un 2
# /home/juan/Desktop/juan/bio/mirna_mite/data/res/all_results.fasta

# %%
path_res_seq
# Out:
# '/home/juan/Desktop/juan/bio/mirna_mite/data/res/all_results.fasta'

# %% [raw]
# blastn -evalue 1e-3 -task blastn -query data/res/all_results.fasta -subject  data/mites_consensus.fasta -outfmt '6 qseqid sseqid qstart qend sstart send mismatch gaps pident evalue length qlen slen qcovs score'  > data/res/blast_mites.csv

# %%
df_trep = pd.read_csv(path_blast_res, sep="\t")
cols = ['qseqid','sseqid','qstart','qend','sstart','send','mismatch','gaps','pident','evalue','length','qlen','slen','qcovs','score']
df_trep.columns = cols
df_trep = df_trep[df_trep.pident >= 80]
df_trep = df_trep[df_trep.qcovs >= 80]
print(len(df_trep.index))
df_trep.head(2)
# Out:
# 499
#                  qseqid     sseqid  qstart  qend  sstart  send  mismatch  \
# 0  sun_all_Cluster_8835  MITE_1712       1    79       2    80         9
# 1  sun_all_Cluster_8835   MITE_233       3    77       4    78         8
#
#    gaps  pident        evalue  length  qlen  slen  qcovs  score
# 0     0  88.608  7.860000e-24      79    80    81     99    112
# 1     4  84.416  1.330000e-14      77    80    80     94     78

# %%
len(df_trep.qseqid.unique())
# Out:
# 28

# %%
df_trep['MITE'] = df_trep.groupby(['qseqid'])['sseqid'].transform(lambda x: ','.join(x))

# %%
df_trep = df_trep[['qseqid','MITE']]

# %%
df_trep.head(2)
# Out:
#                  qseqid                                    MITE
# 0  sun_all_Cluster_8835  MITE_1712,MITE_233,MITE_1717,MITE_1157
# 1  sun_all_Cluster_8835  MITE_1712,MITE_233,MITE_1717,MITE_1157

# %%
df_trep = df_trep.drop_duplicates(subset=['qseqid'], keep='first')

# %%
df_trep.head(2)
# Out:
#                    qseqid                                               MITE
# 0    sun_all_Cluster_8835             MITE_1712,MITE_233,MITE_1717,MITE_1157
# 61  mrcv_all_Cluster_2513  MITE_1151,MITE_1572,MITE_1565,MITE_606,MITE_68...

# %%
len(df_trep.index)
# Out:
# 28

# %%
df = pd.merge(df, df_trep, how='left', left_on='Name', right_on='qseqid')

# %%
df.drop("qseqid", axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                    #Locus                  Name  Length  Reads    RPM  \
# 0  1A:309399489-309399664  mrcv_all_Cluster_872     176    553  4.340
# 1  1A:309399491-309399581  sun_all_Cluster_2789      91    459  3.635
#
#    UniqueReads  FracTop Strand               MajorRNA  MajorRNAReads  ...   \
# 0            1    0.002      -  ACGGCAUAGAGGCACUGCAAA            327  ...
# 1            4    0.007      -  ACGGCAUAGAGGCACUGCAAA            196  ...
#
#    20   21  22  23  24  seqname             position      start        end  \
# 0  35  440  61   5   4       1A  309399489-309399664  309399489  309399664
# 1  94  298  26   0   5       1A  309399491-309399581  309399491  309399581
#
#    MITE
# 0   NaN
# 1   NaN
#
# [2 rows x 26 columns]

# %%
total_count = len(df.index)
total_count
# Out:
# 260

# %%
df_new_not_mites = df[df.MITE.isnull()]
count_not_mites = len(df_new_not_mites.index)
count_not_mites
# Out:
# 232

# %%
df_new_mites = df[df.MITE.notnull()]
count_mites = len(df_new_mites.index)
count_mites
# Out:
# 28

# %%
count_mites * 100 / total_count
# Out:
# 10.76923076923077

# %%
#mirbase

# %%
buffer_seqs = []
for k,v in df.iterrows():
    id = v.Name
    desc = v['#Locus']
    seq = SeqRecord(Seq(v.MajorRNA), id=id, description=desc)
    buffer_seqs.append(seq)
SeqIO.write(buffer_seqs, path_mirna_seq, "fasta")
print(len(buffer_seqs))
print(path_mirna_seq)
# Out:
# 260
# /home/juan/Desktop/juan/bio/mirna_mite/data/res/mirna.y.fasta

# %%
buffer_seqs = []
for k,v in df[df.MITE.notnull()].iterrows():
    id = v.Name
    desc = v['#Locus']
    if "|" in id:
        id = id.split("|")[0]
    seq = SeqRecord(Seq(v.MajorRNA), id=id, description="")
    buffer_seqs.append(seq)
SeqIO.write(buffer_seqs, path_mirna_seq_trep, "fasta")
print(len(buffer_seqs))
print(path_mirna_seq_trep)
# Out:
# 28
# /home/juan/Desktop/juan/bio/mirna_mite/data/res/mirna.y.trep.fasta

# %% [raw]
# blastn -task blastn -evalue 10 -query data/res/mirna.y.fasta -subject data/mature.fa -outfmt '6 qseqid sseqid qstart qend sstart send mismatch gaps pident evalue length qlen slen qcovs score'  > data/res/mirna.y.mature.csv

# %%
df_mirbase = pd.read_csv(path_mirna_mature, sep="\t")
cols = ['qseqid','sseqid','qstart','qend','sstart','send','mismatch','gaps','pident','evalue','length','qlen','slen','qcovs','score']
df_mirbase.columns = cols
print(len(df_mirbase.index))
df_mirbase.head(2)
# Out:
# 17928
#                   qseqid           sseqid  qstart  qend  sstart  send  \
# 0   sun_all_Cluster_2789      ptc-miR1447      10    20      16     6
# 1  mrcv_all_Cluster_1015  tca-miR-6017-5p       5    15      10    20
#
#    mismatch  gaps  pident  evalue  length  qlen  slen  qcovs  score
# 0         0     0   100.0     1.2      11    21    21     52     22
# 1         0     0   100.0     1.3      11    22    20     50     22

# %%
allowed_mirbase_mismatches = 7
mirbase_qlen = 7

# %%
df_mirbase = df_mirbase[df_mirbase.length > df_mirbase.qlen - mirbase_qlen]
print(len(df_mirbase.index))
# Out:
# 16592

# %%
df_mirbase = df_mirbase[df_mirbase.mismatch + df_mirbase.gaps <= allowed_mirbase_mismatches]
print(len(df_mirbase.index))
# Out:
# 16592

# %%
len(df_mirbase.qseqid.unique().tolist())
# Out:
# 164

# %%
df_mirbase = df_mirbase[['qseqid','sseqid']]

# %%
df_mirbase['mirbase'] = df_mirbase.groupby(['qseqid'])['sseqid'].transform(lambda x: ','.join(x))

# %%
df_mirbase = df_mirbase[['qseqid','mirbase']]

# %%
df_mirbase = df_mirbase.drop_duplicates(subset=['qseqid'], keep='first')

# %%
print(len(df_mirbase.index))
df_mirbase.head(2)
# Out:
# 164
#                    qseqid                                            mirbase
# 14   sun_all_Cluster_8835                                        hvu-miR6197
# 20  mrcv_all_Cluster_2061  aof-miR166d,cas-miR166f-3p,cas-miR166d,cas-miR...

# %%
df = pd.merge(df, df_mirbase, how='left', left_on='Name', right_on='qseqid')

# %%
df.drop("qseqid", axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                    #Locus                  Name  Length  Reads    RPM  \
# 0  1A:309399489-309399664  mrcv_all_Cluster_872     176    553  4.340
# 1  1A:309399491-309399581  sun_all_Cluster_2789      91    459  3.635
#
#    UniqueReads  FracTop Strand               MajorRNA  MajorRNAReads   ...     \
# 0            1    0.002      -  ACGGCAUAGAGGCACUGCAAA            327   ...
# 1            4    0.007      -  ACGGCAUAGAGGCACUGCAAA            196   ...
#
#     21  22 23  24  seqname             position      start        end  MITE  \
# 0  440  61  5   4       1A  309399489-309399664  309399489  309399664   NaN
# 1  298  26  0   5       1A  309399491-309399581  309399491  309399581   NaN
#
#    mirbase
# 0      NaN
# 1      NaN
#
# [2 rows x 27 columns]

# %%
len(df.index)
# Out:
# 260

# %%
#genomic annotation

# %%
df_ann = pd.read_csv(path_annotation, index_col=False, sep='\t', comment='#', header=None)
df_ann.columns = ['seqname' , 'source' , 'feature' , 'start' , 'end' , 'score' , 'strand' , 'frame' , 'attribute']

# %%
print(len(df_ann.index))
# Out:
# 2573211

# %%
df_ann = df_ann[
    (df_ann.feature == 'intron') | 
    (df_ann.feature == 'exon') | 
    (df_ann.feature == 'three_prime_UTR') | 
    (df_ann.feature == 'five_prime_UTR')]
print(len(df_ann.index))
# Out:
# 1593666

# %%
df_ann_promoters = pd.read_csv(path_annotation_promoters, index_col=False, sep='\t', comment='#', header=None)
df_ann_promoters.columns = ['seqname' , 'source' , 'feature' , 'start' , 'end' , 'score' , 'strand' , 'frame' , 'attribute']
print(len(df_ann_promoters.index))
# Out:
# 120744

# %%
df_ann_total = pd.concat([df_ann, df_ann_promoters])

# %%
df_ann_total.head(2)
# Out:
#   seqname          source feature  start   end score strand frame  \
# 2      1A  Ensembl_Plants    exon    200  1683     .      +     .
# 5      1A  Ensembl_Plants    exon   5023  6833     .      +     .
#
#                                            attribute
# 2  Parent=transcript:ENSRNA050013875-T1;Name=ENSR...
# 5  Parent=transcript:ENSRNA050013847-T1;Name=ENSR...

# %%
len(df_ann_total.index)
# Out:
# 1714410

# %%
df_anns = {}
for chromosome in df_ann_total.seqname.unique():
    df_anns[chromosome] = df_ann_total[df_ann_total.seqname == chromosome]

# %%
df.head(1)
# Out:
#                    #Locus                  Name  Length  Reads   RPM  \
# 0  1A:309399489-309399664  mrcv_all_Cluster_872     176    553  4.34
#
#    UniqueReads  FracTop Strand               MajorRNA  MajorRNAReads   ...     \
# 0            1    0.002      -  ACGGCAUAGAGGCACUGCAAA            327   ...
#
#     21  22 23  24  seqname             position      start        end  MITE  \
# 0  440  61  5   4       1A  309399489-309399664  309399489  309399664   NaN
#
#    mirbase
# 0      NaN
#
# [1 rows x 27 columns]

# %%
df['annotation'] = 'intergenic'

# %%
for k,v in df.iterrows():
    other = df_anns[v.seqname]
    other = other[(other.end >= v.start) & (other.start <= v.end)]
    if len(other.index) > 0:
        features = set(other.feature.tolist())
        str_features = ', '.join(features)
        if df.loc[k, 'annotation'] == 'three_prime_UTR' or df.loc[k, 'annotation'] == 'five_prime_UTR':
            continue
        df.loc[k, 'annotation'] = str_features

# %%
df.annotation.value_counts().plot('bar')

# %%
#let's have some fun with data

# %%
df[df.MITE.notnull()].annotation.value_counts()
# Out:
# intron                   14
# intergenic               10
# promoter                  2
# exon, three_prime_UTR     2
# Name: annotation, dtype: int64

# %%
from matplotlib.ticker import MaxNLocator
from matplotlib import pyplot
ax = df[df.MITE.notnull()].annotation.value_counts().plot('bar')
x_offset = -0.07
y_offset = 0.15
ax.set_ylim(0,20)
ax.yaxis.set_major_locator(MaxNLocator(integer=True))

for p in ax.patches:
    b = p.get_bbox()
    val = int(b.y1)
    ax.annotate(val, ((b.x0 + b.x1)/2 + x_offset, b.y1 + y_offset))
ax
pyplot.savefig('../data/res/1.png',transparent=True, bbox_inches='tight', pad_inches=0)

# %%
len(df.index)
# Out:
# 260

# %%
print(len(df[df.MITE.notnull()].index))
df[df.MITE.notnull()]
# Out:
# 28
#                      #Locus  \
# 5    1B:161992200-161992280
# 9    1B:565664575-565664794
# 11   1D:147896240-147896319
# 17   2A:133702671-133702770
# 20   2A:168984136-168984233
# 30       2B:5671327-5671460
# 37   2B:482720682-482720772
# 44   2B:720801630-720801713
# 53     3A:19302861-19302943
# 62   3A:746087222-746087306
# 67   3B:253488744-253488823
# 70   3B:587564305-587564383
# 78   3D:472405006-472405092
# 79   3D:508204974-508205052
# 84     4A:67171695-67171971
# 100  4B:429353827-429354091
# 106  4D:142764762-142764979
# 107  4D:142764794-142764971
# 122  5A:552632192-552632284
# 123  5A:609867615-609867781
# 151      5D:6108105-6108490
# 175    6A:23496429-23496595
# 215  6D:361524524-361524682
# 220  6D:461512362-461512720
# 233  7A:668530082-668530159
# 234  7A:668530089-668530164
# 237    7B:34679825-34679952
# 243  7B:223173899-223174050
#
#                                                   Name  Length  Reads     RPM  \
# 5                                 sun_all_Cluster_8835      81    135   1.069
# 9                                mrcv_all_Cluster_2513     220    223   1.750
# 11   mrcv_mites_MITE_T_120271|chr2D|74975911|749759...      80     45   0.353
# 17   sun_mites_MITE_T_99232|chr3B|765723509|7657236...     100   2289  18.126
# 20   mrcv_mites_MITE_T_102616|chr1B|301273397|30127...      98    198   1.554
# 30                               sun_all_Cluster_28681     134    562   4.450
# 37                               sun_all_Cluster_33132      91    102   0.808
# 44                               mrcv_all_Cluster_8534      84    505   3.963
# 53   mrcv_mites_MITE_T_105526|chr3A|638201844|63820...      83    108   0.848
# 62                              mrcv_all_Cluster_12767      85    181   1.421
# 67   mrcv_mites_MITE_T_120628|chr4D|230912845|23091...      80   1099   8.625
# 70                              mrcv_all_Cluster_13743      79     76   0.596
# 78   mrcv_mites_MITE_T_110611|chr6B|503544571|50354...      87    387   3.037
# 79   mrcv_mites_MITE_T_121053|chr7D|349263971|34926...      79    413   3.241
# 84   mrcv_mites_MITE_T_21345|chr5D|55587099|5558740...     277    261   2.048
# 100  mrcv_mites_MITE_T_37538|chr7B|129805762|129806...     265    144   1.130
# 106  mrcv_mites_MITE_T_40344|chr7A|436759709|436759...     218    188   1.475
# 107                              sun_all_Cluster_82408     178     77   0.610
# 122  mrcv_mites_MITE_T_95924|chr2B|774087848|774087...      93     46   0.361
# 123  mrcv_mites_MITE_T_64580|chr5B|410528881|410529...     167    246   1.931
# 151  mrcv_mites_MITE_T_672|chr4A|673785491|67378595...     386    883   6.930
# 175  mrcv_mites_MITE_T_64052|chr7B|176002823|176003...     167    111   0.871
# 215  mrcv_mites_MITE_T_58879|chr6D|41542478|4154267...     159    134   1.052
# 220  mrcv_mites_MITE_T_6223|chr4B|57143112|57143492...     359    409   3.210
# 233  mrcv_mites_MITE_T_100589|chr4B|399946940|39994...      78    577   4.528
# 234                             sun_all_Cluster_136100      76     96   0.760
# 237  mrcv_mites_MITE_T_80536|chr6D|312104065|312104...     128    184   1.444
# 243                             mrcv_all_Cluster_34329     152     80   0.628
#
#      UniqueReads  FracTop Strand                  MajorRNA  MajorRNAReads  \
# 5              5    0.919      +     UCUGUUCACAAAUGUAAGACG            106
# 9              1    0.991      +     CAUUUUCCUAUAGACUUGGUC            142
# 11             1    1.000      +     UAUAUUUUGGUACGGAGGGAU             22
# 17          2181    0.983      +  UGAGACGGGUAAUUUGGAACGGAG           1484
# 20             2    0.045      -    UCGGAAUUAGUUGACACUCAAA             86
# 30           504    0.016      -     UAUCUGGACAAAUCUGAGACA            293
# 37            91    0.078      -     AUCUUCUAUCGUGGGACGAAG             48
# 44           486    1.000      +     AUUGAACUAAGGAGGGGUGGA            386
# 53            10    0.972      +     UCCAAUUACUCGUCGUGGUUU             89
# 62            16    0.000      -     UAAUAUGGAUUGGAGGGGGUA             74
# 67            21    0.002      -     AUAUUAUGUGACAGAAGGAGU            715
# 70            68    1.000      +     AUUGUGUACAGAGGGAGUAGU             67
# 78            64    0.114      -    ACACUUAUUUCCGAUCGGAGGG            223
# 79           382    0.985      +     AACUGCUCCCUCCGUAAACUA            144
# 84           139    0.115      -     ACUUCGAGGACCUGGAUGACU            134
# 100          118    0.993      +     UAAACAUCACAAACUUUGGCC             78
# 106            3    0.952      +     UAGGGUGUAGAAUAAGCUAUU            128
# 107            5    0.831      +     UAGCUUAUUCUACAUCCCAGU             24
# 122            0    0.000      -     UGCGGCACUUAUUUUGGGACG             40
# 123          205    0.947      +     UUGUAGAGCUUUCAUUAUGGA            170
# 151           44    0.003      -     UUUGGACAUCUGACAAGCUCU            765
# 175           18    0.045      -     UUAGAGGUUUCAAUACGGACU             82
# 215            1    0.000      -     UUAGAGAUUUCAAUGUGGAUU            119
# 220          294    0.064      -  AGAUGACCAAAUGAGCUGAAACUU            192
# 233           10    0.972      +     AUGACGAGUAAAUCAGAACGG            257
# 234            2    0.927      +     CUUCUGAUUUACUCGUCGUGG             26
# 237           26    0.989      +     UGUCGUAGAUUUGUCUAGAUA             99
# 243            2    1.000      +     UGGCAAAUCUAGUUGGUGAGC             44
#
#              ...             22   23    24  seqname             position  \
# 5            ...              0    0     2       1B  161992200-161992280
# 9            ...              7    0     0       1B  565664575-565664794
# 11           ...              1    0     0       1D  147896240-147896319
# 17           ...             53  101  2001       2A  133702671-133702770
# 20           ...             89   63     1       2A  168984136-168984233
# 30           ...              5    2     4       2B      5671327-5671460
# 37           ...              1    1     1       2B  482720682-482720772
# 44           ...              5    0     0       2B  720801630-720801713
# 53           ...              4    0     3       3A    19302861-19302943
# 62           ...              3    5    13       3A  746087222-746087306
# 67           ...             10    0     4       3B  253488744-253488823
# 70           ...              1    0     0       3B  587564305-587564383
# 78           ...            228    0    30       3D  472405006-472405092
# 79           ...            171    1     5       3D  508204974-508205052
# 84           ...              2    3    68       4A    67171695-67171971
# 100          ...             12    3     7       4B  429353827-429354091
# 106          ...              1    0     6       4D  142764762-142764979
# 107          ...              0    0    11       4D  142764794-142764971
# 122          ...              0    0     0       5A  552632192-552632284
# 123          ...              1    3    16       5A  609867615-609867781
# 151          ...              3    0     8       5D      6108105-6108490
# 175          ...              0    1     4       6A    23496429-23496595
# 215          ...              6    0     1       6D  361524524-361524682
# 220          ...              9   21   268       6D  461512362-461512720
# 233          ...             27   29    81       7A  668530082-668530159
# 234          ...             14    0    26       7A  668530089-668530164
# 237          ...              0    1    14       7B    34679825-34679952
# 243          ...              5    0     1       7B  223173899-223174050
#
#          start        end                                               MITE  \
# 5    161992200  161992280             MITE_1712,MITE_233,MITE_1717,MITE_1157
# 9    565664575  565664794  MITE_1151,MITE_1572,MITE_1565,MITE_606,MITE_68...
# 11   147896240  147896319  MITE_1717,MITE_1717,MITE_233,MITE_233,MITE_18,...
# 17   133702671  133702770  DTT_Tmon_Icarus_BG607724-1,DTT_Tmon_Icarus_BG6...
# 20   168984136  168984233  MITE_253,MITE_253,MITE_293,MITE_1428,DTT_Taes_...
# 30     5671327    5671460  MITE_798,MITE_798,MITE_148,MITE_148,DTT_Hvul_P...
# 37   482720682  482720772  MITE_1444,MITE_1444,MITE_1030,MITE_1030,DTT_Ta...
# 44   720801630  720801713                                MITE_1643,MITE_1643
# 53    19302861   19302943  MITE_1128,MITE_1128,MITE_792,MITE_792,MITE_975...
# 62   746087222  746087306                                           MITE_660
# 67   253488744  253488823  MITE_1051,DTT_Taes_Athos_BJ275764-1,DTT_Taes_A...
# 70   587564305  587564383                                           MITE_867
# 78   472405006  472405092  MITE_297,MITE_297,MITE_1398,MITE_1398,MITE_176...
# 79   508204974  508205052  DTT_Taes_Athos_BJ282680-1,DTT_Taes_Athos_BJ282...
# 84    67171695   67171971  MITE_1253,MITE_1253,MITE_1253,MITE_933,MITE_93...
# 100  429353827  429354091  MITE_1583,MITE_1583,MITE_812,MITE_236,MITE_470...
# 106  142764762  142764979                                            MITE_45
# 107  142764794  142764971  MITE_45,MITE_45,MITE_45,MITE_490,MITE_490,MITE...
# 122  552632192  552632284  MITE_1338,MITE_1338,MITE_180,DTT_Tdur_Hades_29...
# 123  609867615  609867781  DTT_Atau_Thalos_AF338431-1,MITE_878,DTT_Hvul_T...
# 151    6108105    6108490  MITE_1605,MITE_1605,MITE_617,MITE_423,MITE_914...
# 175   23496429   23496595  DTT_Taes_Thalos_BJ273584-1,MITE_550,DTT_Hvul_T...
# 215  361524524  361524682  MITE_5,DTT_Null_Thalos_consensus-1,DTT_Taes_Th...
# 220  461512362  461512720              MITE_1605,MITE_1589,MITE_423,MITE_617
# 233  668530082  668530159  MITE_1128,MITE_1128,MITE_975,MITE_975,MITE_698...
# 234  668530089  668530164  MITE_1128,MITE_1128,MITE_975,MITE_975,MITE_698...
# 237   34679825   34679952  MITE_1548,MITE_1548,MITE_677,MITE_677,DTT_Taes...
# 243  223173899  223174050                                          MITE_1013
#
#                           mirbase             annotation
# 5                     hvu-miR6197                 intron
# 9                             NaN                 intron
# 11                            NaN                 intron
# 17                            NaN               promoter
# 20                            NaN                 intron
# 30                            NaN                 intron
# 37                            NaN                 intron
# 44                            NaN                 intron
# 53                 tae-miR5175-5p                 intron
# 62                oan-miR-1400-3p  exon, three_prime_UTR
# 67                            NaN                 intron
# 70                            NaN                 intron
# 78                            NaN                 intron
# 79                            NaN             intergenic
# 84                            NaN             intergenic
# 100                           NaN  exon, three_prime_UTR
# 106                           NaN             intergenic
# 107                           NaN             intergenic
# 122  hvu-miR5049c,bdi-miR5181a-3p             intergenic
# 123                           NaN                 intron
# 151                           NaN             intergenic
# 175                           NaN             intergenic
# 215                           NaN                 intron
# 220                           NaN               promoter
# 233                           NaN             intergenic
# 234                           NaN             intergenic
# 237                   hvu-miR6191             intergenic
# 243                           NaN                 intron
#
# [28 rows x 28 columns]

# %%
#list(df[df.MITE.notnull()].MITE.unique())

# %%
df[(df.MITE.notnull()) & (df.mirbase.notnull())]
# Out:
#                      #Locus  \
# 5    1B:161992200-161992280
# 53     3A:19302861-19302943
# 62   3A:746087222-746087306
# 122  5A:552632192-552632284
# 237    7B:34679825-34679952
#
#                                                   Name  Length  Reads    RPM  \
# 5                                 sun_all_Cluster_8835      81    135  1.069
# 53   mrcv_mites_MITE_T_105526|chr3A|638201844|63820...      83    108  0.848
# 62                              mrcv_all_Cluster_12767      85    181  1.421
# 122  mrcv_mites_MITE_T_95924|chr2B|774087848|774087...      93     46  0.361
# 237  mrcv_mites_MITE_T_80536|chr6D|312104065|312104...     128    184  1.444
#
#      UniqueReads  FracTop Strand               MajorRNA  MajorRNAReads  \
# 5              5    0.919      +  UCUGUUCACAAAUGUAAGACG            106
# 53            10    0.972      +  UCCAAUUACUCGUCGUGGUUU             89
# 62            16    0.000      -  UAAUAUGGAUUGGAGGGGGUA             74
# 122            0    0.000      -  UGCGGCACUUAUUUUGGGACG             40
# 237           26    0.989      +  UGUCGUAGAUUUGUCUAGAUA             99
#
#              ...            22 23  24  seqname             position  \
# 5            ...             0  0   2       1B  161992200-161992280
# 53           ...             4  0   3       3A    19302861-19302943
# 62           ...             3  5  13       3A  746087222-746087306
# 122          ...             0  0   0       5A  552632192-552632284
# 237          ...             0  1  14       7B    34679825-34679952
#
#          start        end                                               MITE  \
# 5    161992200  161992280             MITE_1712,MITE_233,MITE_1717,MITE_1157
# 53    19302861   19302943  MITE_1128,MITE_1128,MITE_792,MITE_792,MITE_975...
# 62   746087222  746087306                                           MITE_660
# 122  552632192  552632284  MITE_1338,MITE_1338,MITE_180,DTT_Tdur_Hades_29...
# 237   34679825   34679952  MITE_1548,MITE_1548,MITE_677,MITE_677,DTT_Taes...
#
#                           mirbase             annotation
# 5                     hvu-miR6197                 intron
# 53                 tae-miR5175-5p                 intron
# 62                oan-miR-1400-3p  exon, three_prime_UTR
# 122  hvu-miR5049c,bdi-miR5181a-3p             intergenic
# 237                   hvu-miR6191             intergenic
#
# [5 rows x 28 columns]

# %%
df[df.MITE.notnull()][['#Locus','Name','MajorRNA','MITE','annotation','mirbase']]
# Out:
#                      #Locus  \
# 5    1B:161992200-161992280
# 9    1B:565664575-565664794
# 11   1D:147896240-147896319
# 17   2A:133702671-133702770
# 20   2A:168984136-168984233
# 30       2B:5671327-5671460
# 37   2B:482720682-482720772
# 44   2B:720801630-720801713
# 53     3A:19302861-19302943
# 62   3A:746087222-746087306
# 67   3B:253488744-253488823
# 70   3B:587564305-587564383
# 78   3D:472405006-472405092
# 79   3D:508204974-508205052
# 84     4A:67171695-67171971
# 100  4B:429353827-429354091
# 106  4D:142764762-142764979
# 107  4D:142764794-142764971
# 122  5A:552632192-552632284
# 123  5A:609867615-609867781
# 151      5D:6108105-6108490
# 175    6A:23496429-23496595
# 215  6D:361524524-361524682
# 220  6D:461512362-461512720
# 233  7A:668530082-668530159
# 234  7A:668530089-668530164
# 237    7B:34679825-34679952
# 243  7B:223173899-223174050
#
#                                                   Name  \
# 5                                 sun_all_Cluster_8835
# 9                                mrcv_all_Cluster_2513
# 11   mrcv_mites_MITE_T_120271|chr2D|74975911|749759...
# 17   sun_mites_MITE_T_99232|chr3B|765723509|7657236...
# 20   mrcv_mites_MITE_T_102616|chr1B|301273397|30127...
# 30                               sun_all_Cluster_28681
# 37                               sun_all_Cluster_33132
# 44                               mrcv_all_Cluster_8534
# 53   mrcv_mites_MITE_T_105526|chr3A|638201844|63820...
# 62                              mrcv_all_Cluster_12767
# 67   mrcv_mites_MITE_T_120628|chr4D|230912845|23091...
# 70                              mrcv_all_Cluster_13743
# 78   mrcv_mites_MITE_T_110611|chr6B|503544571|50354...
# 79   mrcv_mites_MITE_T_121053|chr7D|349263971|34926...
# 84   mrcv_mites_MITE_T_21345|chr5D|55587099|5558740...
# 100  mrcv_mites_MITE_T_37538|chr7B|129805762|129806...
# 106  mrcv_mites_MITE_T_40344|chr7A|436759709|436759...
# 107                              sun_all_Cluster_82408
# 122  mrcv_mites_MITE_T_95924|chr2B|774087848|774087...
# 123  mrcv_mites_MITE_T_64580|chr5B|410528881|410529...
# 151  mrcv_mites_MITE_T_672|chr4A|673785491|67378595...
# 175  mrcv_mites_MITE_T_64052|chr7B|176002823|176003...
# 215  mrcv_mites_MITE_T_58879|chr6D|41542478|4154267...
# 220  mrcv_mites_MITE_T_6223|chr4B|57143112|57143492...
# 233  mrcv_mites_MITE_T_100589|chr4B|399946940|39994...
# 234                             sun_all_Cluster_136100
# 237  mrcv_mites_MITE_T_80536|chr6D|312104065|312104...
# 243                             mrcv_all_Cluster_34329
#
#                      MajorRNA  \
# 5       UCUGUUCACAAAUGUAAGACG
# 9       CAUUUUCCUAUAGACUUGGUC
# 11      UAUAUUUUGGUACGGAGGGAU
# 17   UGAGACGGGUAAUUUGGAACGGAG
# 20     UCGGAAUUAGUUGACACUCAAA
# 30      UAUCUGGACAAAUCUGAGACA
# 37      AUCUUCUAUCGUGGGACGAAG
# 44      AUUGAACUAAGGAGGGGUGGA
# 53      UCCAAUUACUCGUCGUGGUUU
# 62      UAAUAUGGAUUGGAGGGGGUA
# 67      AUAUUAUGUGACAGAAGGAGU
# 70      AUUGUGUACAGAGGGAGUAGU
# 78     ACACUUAUUUCCGAUCGGAGGG
# 79      AACUGCUCCCUCCGUAAACUA
# 84      ACUUCGAGGACCUGGAUGACU
# 100     UAAACAUCACAAACUUUGGCC
# 106     UAGGGUGUAGAAUAAGCUAUU
# 107     UAGCUUAUUCUACAUCCCAGU
# 122     UGCGGCACUUAUUUUGGGACG
# 123     UUGUAGAGCUUUCAUUAUGGA
# 151     UUUGGACAUCUGACAAGCUCU
# 175     UUAGAGGUUUCAAUACGGACU
# 215     UUAGAGAUUUCAAUGUGGAUU
# 220  AGAUGACCAAAUGAGCUGAAACUU
# 233     AUGACGAGUAAAUCAGAACGG
# 234     CUUCUGAUUUACUCGUCGUGG
# 237     UGUCGUAGAUUUGUCUAGAUA
# 243     UGGCAAAUCUAGUUGGUGAGC
#
#                                                   MITE             annotation  \
# 5               MITE_1712,MITE_233,MITE_1717,MITE_1157                 intron
# 9    MITE_1151,MITE_1572,MITE_1565,MITE_606,MITE_68...                 intron
# 11   MITE_1717,MITE_1717,MITE_233,MITE_233,MITE_18,...                 intron
# 17   DTT_Tmon_Icarus_BG607724-1,DTT_Tmon_Icarus_BG6...               promoter
# 20   MITE_253,MITE_253,MITE_293,MITE_1428,DTT_Taes_...                 intron
# 30   MITE_798,MITE_798,MITE_148,MITE_148,DTT_Hvul_P...                 intron
# 37   MITE_1444,MITE_1444,MITE_1030,MITE_1030,DTT_Ta...                 intron
# 44                                 MITE_1643,MITE_1643                 intron
# 53   MITE_1128,MITE_1128,MITE_792,MITE_792,MITE_975...                 intron
# 62                                            MITE_660  exon, three_prime_UTR
# 67   MITE_1051,DTT_Taes_Athos_BJ275764-1,DTT_Taes_A...                 intron
# 70                                            MITE_867                 intron
# 78   MITE_297,MITE_297,MITE_1398,MITE_1398,MITE_176...                 intron
# 79   DTT_Taes_Athos_BJ282680-1,DTT_Taes_Athos_BJ282...             intergenic
# 84   MITE_1253,MITE_1253,MITE_1253,MITE_933,MITE_93...             intergenic
# 100  MITE_1583,MITE_1583,MITE_812,MITE_236,MITE_470...  exon, three_prime_UTR
# 106                                            MITE_45             intergenic
# 107  MITE_45,MITE_45,MITE_45,MITE_490,MITE_490,MITE...             intergenic
# 122  MITE_1338,MITE_1338,MITE_180,DTT_Tdur_Hades_29...             intergenic
# 123  DTT_Atau_Thalos_AF338431-1,MITE_878,DTT_Hvul_T...                 intron
# 151  MITE_1605,MITE_1605,MITE_617,MITE_423,MITE_914...             intergenic
# 175  DTT_Taes_Thalos_BJ273584-1,MITE_550,DTT_Hvul_T...             intergenic
# 215  MITE_5,DTT_Null_Thalos_consensus-1,DTT_Taes_Th...                 intron
# 220              MITE_1605,MITE_1589,MITE_423,MITE_617               promoter
# 233  MITE_1128,MITE_1128,MITE_975,MITE_975,MITE_698...             intergenic
# 234  MITE_1128,MITE_1128,MITE_975,MITE_975,MITE_698...             intergenic
# 237  MITE_1548,MITE_1548,MITE_677,MITE_677,DTT_Taes...             intergenic
# 243                                          MITE_1013                 intron
#
#                           mirbase
# 5                     hvu-miR6197
# 9                             NaN
# 11                            NaN
# 17                            NaN
# 20                            NaN
# 30                            NaN
# 37                            NaN
# 44                            NaN
# 53                 tae-miR5175-5p
# 62                oan-miR-1400-3p
# 67                            NaN
# 70                            NaN
# 78                            NaN
# 79                            NaN
# 84                            NaN
# 100                           NaN
# 106                           NaN
# 107                           NaN
# 122  hvu-miR5049c,bdi-miR5181a-3p
# 123                           NaN
# 151                           NaN
# 175                           NaN
# 215                           NaN
# 220                           NaN
# 233                           NaN
# 234                           NaN
# 237                   hvu-miR6191
# 243                           NaN

# %%
df.to_csv(path_res, sep='\t', index=None)
print(len(df.index))
print(path_res)
# Out:
# 260
# /home/juan/Desktop/juan/bio/mirna_mite/data/res/all_results.csv
